# %%
import kin

# %%
kin.run()
# Out:
# 도 사용하고 계십니다. 넘 힘들어요 그래서 키로그 프로그램을 다운받고싶은데 다운받을수있는 방법 있나요..?
#
# title: 조르당 루카쿠와 로멜로 루카쿠는 같은집에 사나요?
# previewContents 로멜로 루카쿠는 잉글랜드에 있다가 세리에로 넘어왔는데, 원래 세리에에서 뛰었던 로멜루 루카쿠의 형 조르당 루카쿠는 같은 집에 사나요? 아니면 다른 집에 사나요?
#
# title: 오수 비트맵
# previewContents Osu이거 비트맵 이름 알려주세염https://youtu.be/UfASO7mSR5s
#
# title: 닌텐도 스위치 프리파라
# previewContents 닌텐도 스위치 프리파라를 하고있는데 일본어를 1도 몰라서 랭크가 뭔지 하나도 모르겠어용 지금 신급인데 그 랭크를 한국어로 번역한 표같은거 없을까용??
#
# title: 리듬닥터 데모
# previewContents 리듬닥터 데모&lt;&lt;스팀&gt;&gt;버전 데모 어떻게 받나요ㅗㅇ
#
# title: psn 한 번 결제로 두 개의 플스에서 사용 가능한가요?
# previewContents 동생하고 GTA나 몬헌같은 멀티 플레이 게임을 하려 하는데 한 기기에서만 psn 결제하고 공유 가능한가요? 성실한 답변 부탁드립니다.
#
# title: 중국판 아이러브니키(기적난난) 업데이트 다운로드오류
# previewContents 오늘 중판니키 업데이트 다운로드하는데 자꾸 3%남겨놓고 실패라고 뜨고 다운로드 진행이 되지 않아요 폰은 안드로이드고 공식홈에서 다운받아서 했고 앱을 삭제했다가 다시깔고 별방법다해봤어요 제발좀 도와주세요 ㅠㅠ
#
# title: 트러블슈터
# previewContents 트러블슈터 노가다할 때 매번 반복해야하나요? 자동있나요?
#
# title: 월페이퍼 엔진 오류
# previewContents 잘 되다가 어느 날 부터 갑자기 이러더라구요 언어는 이상하게 나오고 화면은 하얀색으로 혹시 오류 원인이 뭔지 알고 해결법이 있나요?
#
# ...
